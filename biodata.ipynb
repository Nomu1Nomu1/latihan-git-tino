# %%
nama_panggilan = "Tino"
tim_robot = "Werkudara"
hobi = "baca buku"

print(f"Halo namaku {nama_panggilan}, aku berada di tim {tim_robot} dan aku hobi memiliki hobi {hobi}")

# %% [markdown]
# Tino Werkudara hobi baca buku
